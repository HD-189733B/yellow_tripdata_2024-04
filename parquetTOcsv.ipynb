# %%
pip install pandas pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.8 MB 435.7 kB/s eta 0:01:00
#    ---------------------------------------- 0.1/25.8 MB 653.6 kB/s eta 0:00:40
#    ---------------------------------------- 0.1/25.8 MB 983.0 kB/s eta 0:00:27
#    ---------------------------------------- 0.2/25.8 MB 1.1 MB/s eta 0:00:24
#    ---------------------------------------- 0.3/25.8 MB 1.2 MB/s eta 0:00:22
#     --------------------------------------- 0.3/25.8 MB 1.2 MB/s eta 0:00:21
#     --------------------------------------- 0.4/25.8 MB 1.3 MB/s eta 0:00:20
#     --------------------------------------- 0.5/25.8 MB 1.3 MB/s eta 0:00:20
#     --------------------------------------- 0.5/25.8 MB 1.3 MB/s eta 0:00:19
#     --------------------------------------- 0.6/25.8 MB 1.4 MB/s eta 0:00:19
# ...

# %%
import pandas as pd

# Read the Parquet file
parquet_file = 'D:/yellow_tripdata_2024-04.parquet'
df = pd.read_parquet(parquet_file)

# Save as CSV
csv_file = 'D:/yellow_tripdata_2024-04.csv'
df.to_csv(csv_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     260 self.writer = csvlib.writer(
#     261     handles.handle,
#     262     lineterminator=self.lineterminator,
#    (...)
#     267     quotechar=self.quotechar,
#     268 )
# --> 270 self._save()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     274     self._save_header()
# --> 275 self._save_body()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# ...
